# %% [markdown]
# # Script for the visualization
#
# We'll create a function that inputs the list of skills we want to look for, and output a visualization

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('export_usa.csv')
data
# Out:
#                                               pos_clean  \
# 0                                  development director
# 1     an ostentatiously-excitable principal research...
# 2                                        data scientist
# 3                                          data analyst
# 4     assistant professor -tt - signal processing & ...
# ...                                                 ...
# 6948          data developer / machine learning analyst
# 6949                                        scientist i
# 6950                                   intern scientist
# 6951                    senior data & applied scientist
# 6952            principal data scientist, deep learning
#
#                                                descr_cl
# 0     Development DirectorALS Therapy Development In...
# 1     Job Description"The road that leads to accompl...
# 2     Growing company located in the Atlanta, GA are...
# 3     DEPARTMENT: Program OperationsPOSITION LOCATIO...
# 4     DESCRIPTIONThe Emory University Department of ...
# ...                                                 ...
# 6948  Are you data-driven? We at NetApp believe in t...
# 6949  Pharmacyclics is committed to the development ...
# 6950  Oath, a subsidiary of Verizon, is a values-led...
# 6951  We are the Bing Core Relevance team responsibl...
# 6952  Comcast’s Technology &amp; Product organizatio...
#
# [6953 rows x 2 columns]

# %%
#Function inputs

position = "data scientist" #input a string 
keywords = ['python','r','statistics','sql','model','ai',
            'mining','tableau','scikit','pandas','ml',
            'excel','visualization','databases','help',
            'algorithms','analytics','interpersonal',
            'analyze','training','communication','leadership']

position_words = position.lower().replace("data"," ").strip().split()
position_words

#If not a string, break function and print error message
# Out:
# ['scientist']

# %%
#Creating a reduced dataset following position, and counting the number of matches of the search 
data['pos-in-data'] =[True if all (word in position for word in position_words) else False for position in data['pos_clean'] ]

reduced_data = data[data['pos-in-data']]

num_of_matches = len(reduced_data)
reduced_data.head()
# Out:
#                                             pos_clean  \
# 1   an ostentatiously-excitable principal research...
# 2                                      data scientist
# 7   junior to mid-level engineer, geologist or env...
# 9   senior associate - cognitive data scientist na...
# 11                          health scientist iii-cpts
#
#                                              descr_cl  pos-in-data
# 1   Job Description"The road that leads to accompl...         True
# 2   Growing company located in the Atlanta, GA are...         True
# 7   Overview / ResponsibilitiesWood Environment &a...         True
# 9   Known for being a great place to work and buil...         True
# 11  Chenega Professional &amp; Technical Services,...         True

# %%
#Now we split the descriptions, turn it in a list and we remove all stopwords that have no meaning for our analysis 
#we declare a function for it 
def remove_stop_split(x):
    import re
    """
    This function will have a string as an input, check all the words inside and return a string without
    any of these stopwords, and in lowercase.
    """
    stop = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", 
        "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", 
        "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", 
        "theirs", "themselves", "what", "which", "who", "whom", "this", "that", 
        "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", 
        "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", 
        "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at",
        "by", "for", "with", "about", "against", "between", "into", "through", "during",
        "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", 
        "on", "off", "over", "under", "again", "further", "then", "once", "here", "there",
        "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most",
        "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", 
        "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]
    out = []
    descr = re.sub(r'[^\w\s]+'," ",x)
    for word in descr.split():
        if word not in stop:
            out.append(word.lower())
    return out

#and we execute the cleaning 
reduced_data['descr_words'] = [remove_stop_split(des) for des in reduced_data['descr_cl']]
reduced_data
# Out:
# <ipython-input-18-e19cd6abec84>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data['descr_words'] = [remove_stop_split(des) for des in reduced_data['descr_cl']]
#                                               pos_clean  \
# 1     an ostentatiously-excitable principal research...
# 2                                        data scientist
# 7     junior to mid-level engineer, geologist or env...
# 9     senior associate - cognitive data scientist na...
# 11                            health scientist iii-cpts
# ...                                                 ...
# 6947                   senior data scientist (gec11902)
# 6949                                        scientist i
# 6950                                   intern scientist
# 6951                    senior data & applied scientist
# 6952            principal data scientist, deep learning
#
#                                                descr_cl  pos-in-data  \
# 1     Job Description"The road that leads to accompl...         True
# 2     Growing company located in the Atlanta, GA are...         True
# 7     Overview / ResponsibilitiesWood Environment &a...         True
# 9     Known for being a great place to work and buil...         True
# 11    Chenega Professional &amp; Technical Services,...         True
# ...                                                 ...          ...
# 6947  Position DescriptionProficient in Java or Pyth...         True
# 6949  Pharmacyclics is committed to the development ...         True
# 6950  Oath, a subsidiary of Verizon, is a values-led...         True
# 6951  We are the Bing Core Relevance team responsibl...         True
# 6952  Comcast’s Technology &amp; Product organizatio...         True
#
#                                             descr_words
# 1     [job, description, the, road, leads, accomplis...
# 2     [growing, company, located, atlanta, ga, area,...
# 7     [overview, responsibilitieswood, environment, ...
# 9     [known, great, place, work, build, career, kpm...
# 11    [chenega, professional, amp, technical, servic...
# ...                                                 ...
# 6947  [position, descriptionproficient, java, python...
# 6949  [pharmacyclics, committed, development, commer...
# 6950  [oath, subsidiary, verizon, values, led, compa...
# 6951  [we, bing, core, relevance, team, responsible,...
# 6952  [comcast, technology, amp, product, organizati...
#
# [2645 rows x 4 columns]

# %%
# We create a dictionary with the inputted strings, the count, and we calcualte its percentage 
skills=[]
count=[]
percentage=[]
for skill in keywords:
    skills.append(skill)
    word_check = [True if skill in descr else False for descr in reduced_data['descr_words']]
    count.append(sum (word_check))
    percentage.append(sum(word_check)*100/len(word_check))
    
dict = {'Skill': skills, 'Count': count, '% Total': percentage}

# %%
#and we create a dataframe 
df = pd.DataFrame(dict)
df = df.sort_values(by=['% Total'],ascending = False)
df = df.reset_index(drop = True)
df
# Out:
#             Skill  Count    % Total
# 0   communication   1421  53.724008
# 1          python   1277  48.279773
# 2               r   1176  44.461248
# 3      statistics   1096  41.436673
# 4            help   1029  38.903592
# 5       analytics    903  34.139887
# 6      algorithms    799  30.207940
# 7             sql    669  25.293006
# 8         analyze    632  23.894140
# 9          mining    484  18.298677
# 10          model    477  18.034026
# 11     leadership    467  17.655955
# 12       training    443  16.748582
# 13  visualization    402  15.198488
# 14  interpersonal    335  12.665406
# 15      databases    300  11.342155
# 16             ai    297  11.228733
# 17             ml    224   8.468809
# 18          excel    213   8.052930
# 19        tableau    185   6.994329
# 20         scikit    127   4.801512
# 21         pandas    111   4.196597

# %%
#We want to visualze the percentage of appearances of each skill in all data scientist job postings

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

fig_title = "Keywords for '"+ position+ "' positions."

sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set(font_scale=1.8)  # crazy big
plt.figure(figsize=(19, 10))
sns_plot = sns.barplot(y='Skill',x = '% Total', data = df,palette="rocket",).set_title(fig_title)


fig = sns_plot.get_figure()
